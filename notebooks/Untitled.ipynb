# %%
import pandas as pd

# %%
wines = pd.read_csv('../wine.csv')

wines
# Out:
#     alcohol category      country  \
# 0      13.5    White    Argentina
# 1      13.5    White  New Zealand
# 2      13.5      Red           US
# 3      13.7      Red           US
# 4      14.5      Red           US
# 5      12.5      Red       France
# 6      13.3      Red           US
# 7      14.3      Red           US
# 8      12.8      Red           US
# 9      13.9      Red    Argentina
# 10     13.5    White           US
# 11     13.1      Red    Argentina
# 12     12.5      Red       France
# 13     12.5      Red       France
# 14     13.5      Red           US
# 15      NaN      Red    Argentina
# 16     14.5      Red    Argentina
# 17     13.8      Red           US
# 18     12.5      Red       France
# 19     14.5      Red           US
#
#                                           description  \
# 0   Mildly oxidized, oily aromas are low on fruit ...
# 1   This shows confected peach, pineapple and bana...
# 2   This is a fruity, soft-textured and rounded wi...
# ...
